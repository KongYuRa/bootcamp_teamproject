# %%
from llm_module.docs_utils import *
from llm_module.db_utils import *
from llm_module.script_utils import *
from llm_module.llm_utils import *
from llm_module.translator_module import translator
import random


json_files = [
    "./documents/filtered_unsolved_cases.json",
    "./documents/korea_crime.json",
]
titles = title_json_data(json_files)
sample_titles = titles[0:11]

store = {}
conversation_session = {}
ID = "test40"
# LANG_CODE = "jpn_Jpan"
LANG_CODE = False
LANG = "korean"


while True:
    print("================================")
    path = "./db/script_db"
    db_name = "script_db"
    script_db = load_vstore(db_name, path)
    query = input("어떤 이야기가 듣고 싶으신가요?")
    print(query)

    if query.lower() == "exit":
        print("대화를 종료합니다.")
        query = False
        break
    elif query is None or "아무거나" in query.strip():
        print("재미난 이야기를 가져오는 중...")
        choice = random.choice(sample_titles)
        query = choice
        print(choice)

    relavence = evaluator(query, script_db)
    print(relavence[0])
    if relavence[0] < 80:
        print(
            "모르는 이야기 입니다.",
            "종료 : exit",
            "다시 물어보기 : return",
            "생성하기 : create",
        )
        user_input = input("입력하세요.")
        if user_input.lower() == "exit":
            print("대화를 종료합니다.")
            query = False
            break
        elif user_input.lower() == "return":
            continue

        elif user_input.lower() == "create":
            text_input = input("URL 또는 텍스트를 입력해주세요.")
            new_script = script_maker(text_input)
            add_to_vstore(new_script, script_db)
            print("생성이 완료되었습니다.", "다시 답변해주세요.")
            continue

    elif relavence[0] < 95 and relavence[0] >= 80:
        print("더 자세히 이야기 해주세요")
        continue
    elif relavence[0] >= 95:
        script = relavence[1]
        break

if query:
    chain = chain_maker(script, LANG)
    h_chain = history_chain(chain, store)
    response = h_chain.stream(
        # 질문 입력
        {"question": query},
        # 세션 ID 기준으로 대화를 기록합니다.
        config={"configurable": {"session_id": ID}},
    )
    for chunk in response:
        print(chunk, end="", flush=True)

    while True:
        print("\n========================\n")
        query = input("반응을 입력하세요.")
        if query.lower() == "exit":
            print("대화를 종료합니다.")
            break
        response = h_chain.stream(
            # 질문 입력
            {"question": query},
            # 세션 ID 기준으로 대화를 기록합니다.
            config={"configurable": {"session_id": ID}},
        )
        if LANG_CODE:
            print(translator(query, LANG_CODE))
        else:
            print(query)
        print("\n답변:\n")
        for chunk in response:
            print(chunk, end="", flush=True)
            
print(f"[대화 세션ID]: {ID}")
conversation_session[ID] = script
# Out:
# ================================
# 위조지폐 유통 사건
# 100
# [대화 세션ID]: test40
# [대화 세션ID]: test40
# 어떤 일이 벌어지면, 그 뒤에 숨겨진 진실이 궁금해지지 않아? 오늘 이야기할 사건은 바로 77246 위조지폐 유통 사건이야. 이 사건은 단순한 범죄가 아니라, 우리 사회의 신뢰를 흔들었던 사건이었어. 자, 그럼 이야기를 시작해볼까?
#
# 김모 씨라는 한 남자가 있었어. 그는 2년제 전문학교에서 컴퓨터 디자인을 전공했는데, 경제적 어려움 때문에 위조지폐를 만들기로 결심하게 돼. 그의 범행은 단순한 범죄를 넘어서, 사회 전반에 걸친 신뢰 문제를 일으키게 되지.
#
# 2005년부터 2013년까지 이어진 이 사건은 많은 사람들에게 큰 충격을 주었고, 한국은행과 경찰은 긴급 대응을 하게 돼. 김모 씨는 처음에는 여러 권종의 지폐를 시험삼아 위조했는데, 특히 5000원권을 선택한 이유는 그 지폐의 위조 방지 장치가 허술하다는 점이었어.
#
# 그의 범행은 점차 조직적이고 치밀하게 진행되었고, 결국 2005년 3월부터 본격적으로 위조지폐를 유통시키기 시작했지. 그는 CCTV가 없는 상점에서 위조지폐를 사용하며, 가장 저렴한 물건을 구매한 후 잔돈으로 생계를 이어갔어.
#
# 그런데, 이렇게 쉽게 위조지폐가 유통될 수 있었던 이유는 뭘까?
#
# 너는 어떻게 생각해?
# ========================
#
# 대화를 종료합니다.
# [대화 세션ID]: test40

# %%
conversation_session
# Out:
# {'test40': '# 제목 : 77246 위조지폐 유통 사건\n\n# 프롤로그 1 : 사건에 대한 다큐멘터리\n- 내용 : 77246 위조지폐 유통 사건은 한국에서 발생한 위조지폐 사건 중 하나로, 범인이 만든 위조지폐가 높은 품질로 인해 일반인들이 쉽게 속아 넘어갔던 사건이다. 이 사건은 한국은행과 경찰의 긴급 대응을 촉발시켰고, 위조지폐의 유통이 사회에 미친 영향을 다룬 다큐멘터리가 여러 차례 방영되었다.\n\n# 프롤로그 2 : 사건의 배경\n- 내용 : 2005년부터 2013년까지 이어진 이 사건은 범인이 위조지폐를 유통시키면서 발생한 여러 사건과 사회적 반향을 포함하고 있다. 위조지폐는 일반인들에게 쉽게 사용되었고, 그로 인해 금융기관과 한국은행은 큰 혼란을 겪었다. 이 사건은 단순한 범죄를 넘어 사회 전반에 걸친 신뢰 문제를 야기했다.\n\n# 프롤로그 3 : 범인 김모 씨\n- 내용 : 범인 김모 씨는 2년제 전문학교에서 컴퓨터 디자인을 전공한 인물로, 경제적 어려움으로 인해 위조지폐를 만들기로 결심하게 되었다. 그의 개인적인 배경과 범행 동기는 사건의 전개에 중요한 요소로 작용했다.\n\n# 전개 1 : 사건의 역사적 배경\n- 내용 : 2000년대 초반, 한국은 경제적 불황과 함께 다양한 범죄가 증가하던 시기였다. 특히 위조지폐와 같은 금융 범죄는 사회적 문제로 대두되었고, 이에 대한 대책이 필요했다. 그러나 김모 씨의 범행은 이러한 대책이 미비한 틈을 타게 되었다.\n\n# 전개 2 : 김모 씨의 범행 이력\n- 내용 : 김모 씨는 2003년부터 위조지폐 제작을 시작했으며, 처음에는 여러 권종의 지폐를 시험삼아 위조했다. 그는 특히 5000원권을 선택한 이유로, 이 지폐가 상대적으로 위조 방지 장치가 허술하다는 점을 들었다. 그의 범행은 점차 조직적이고 치밀하게 진행되었다.\n\n# 전개 3 : 사건의 시작\n- 내용 : 2005년 3월, 김모 씨는 본격적으로 위조지폐를 유통시키기 시작했다. 그는 주로 CCTV가 없는 상점에서 위조지폐를 사용하며, 가장 저렴한 물건을 구매한 후 잔돈으로 생계를 이어갔다. 이 과정에서 그는 위조지폐의 유통을 더욱 확산시켰다.\n\n# 발전 1 : 상황과 행동\n- 내용 : 김모 씨는 위조지폐를 유통시키는 과정에서 매우 조심스러웠다. 그는 주로 나이가 많은 상점 주인이나 CCTV가 없는 장소를 선택하여 위조지폐를 사용했다. 이러한 행동은 그가 범행을 지속할 수 있는 중요한 요소가 되었다.\n\n# 발전 2 : 사건의 영향\n- 내용 : 위조지폐의 유통은 금융기관과 일반인들에게 큰 혼란을 초래했다. 많은 사람들이 위조지폐를 사용하다가 은행에 입금할 때 비로소 위조임을 알게 되었고, 이는 사회 전반에 걸쳐 신뢰 문제를 야기했다. 한국은행은 이 문제를 해결하기 위해 신권 도입을 결정하게 된다.\n\n# 발전 3 : 사람들의 반응\n- 내용 : 사건이 발생한 후, 많은 사람들은 위조지폐에 대한 경각심을 가지게 되었다. 그러나 여전히 많은 이들이 위조지폐를 진폐로 착각하여 사용하고 있었고, 이는 사건의 심각성을 더욱 부각시켰다. 특히 은행에서도 위조지폐를 쉽게 받아들이는 경우가 많아, 금융기관의 신뢰성에도 타격을 주었다.\n\n# 클라이맥스 1 : 사건의 확대\n- 내용 : 2006년과 2007년, 위조지폐의 발견 사례가 급증하면서 사건은 더욱 확대되었다. 한국은행은 위조지폐의 유통을 막기 위해 긴급 대책을 마련하게 되었고, 범인 검거를 위한 수사가 본격적으로 시작되었다.\n\n# 클라이맥스 2 : 드라마틱한 행동과 갈등\n- 내용 : 범인 김모 씨는 검거를 피하기 위해 더욱 치밀하게 행동했지만, 결국 경찰의 추적을 피할 수 없었다. 경찰은 여러 단서를 통해 김모 씨의 범행을 추적하였고, 그의 검거는 사건의 전환점을 가져왔다.\n\n# 클라이맥스 3 : 사건의 마무리\n- 내용 : 2013년, 김모 씨는 결국 검거되었고, 그의 범행은 사회에 큰 충격을 주었다. 사건이 종결되었지만, 위조지폐는 여전히 유통되고 있었고, 이는 사건의 여파가 얼마나 오래 지속될지를 보여주었다.\n\n# 결말 : 사건의 해결\n- 내용 : 김모 씨는 통화위조죄 및 사기 등의 혐의로 징역 8년형을 선고받았다. 그러나 그의 범행으로 인해 발생한 사회적 혼란은 쉽게 회복되지 않았다. 한국은행은 위조지폐 문제를 해결하기 위해 신권 도입과 같은 대책을 마련하게 되었다.\n\n# 에필로그 : 남은 메시지\n- 내용 : 77246 위조지폐 사건은 단순한 범죄 사건이 아니라, 사회 전반에 걸친 신뢰 문제와 금융 시스템의 취약성을 드러낸 사건이었다. 이 사건을 통해 우리는 범죄 예방과 금융 교육의 중요성을 다시 한번 깨닫게 되었다. 사건 이후에도 위조지폐는 여전히 발견되고 있으며, 이는 범죄가 사회에 미치는 영향을 여전히 경계해야 함을 상기시킨다.'}

# %%
chain = chain_maker(conversation_session['test40'], LANG)
h_chain = history_chain(chain, store)
while True:
        print(f"[대화 세션ID]: {ID}")
        print("\n========================\n")
        query = input("반응을 입력하세요.")
        if query.lower() == "exit":
            print("대화를 종료합니다.")
            break
        response = h_chain.stream(
            # 질문 입력
            {"question": query},
            # 세션 ID 기준으로 대화를 기록합니다.
            config={"configurable": {"session_id": ID}},
        )
        if LANG_CODE:
            print(f'사용자 : {translator(query, LANG_CODE)}')
        else:
            print(f'사용자 : {query}')
        print("\n답변:")
        for chunk in response:
            print(chunk, end="", flush=True)
print(f"[대화 세션ID]: {ID}")
# Out:
# [대화 세션ID]: test40
#
# ========================
#
# 사용자 : 어디까지 이야기 했지?
#
# 답변:
# [대화 세션ID]: test40
# 우리가 이야기한 건 김모 씨라는 남자의 배경과 그가 위조지폐를 만들기로 결심한 이유였어. 그리고 2005년부터 본격적으로 위조지폐를 유통시키기 시작한 상황까지였지. 그가 CCTV가 없는 상점에서 저렴한 물건을 사서 잔돈으로 생계를 이어갔다는 것도 이야기했어.
#
# 그런데, 이렇게 쉽게 위조지폐가 유통될 수 있었던 이유는 뭘까? 너는 어떻게 생각해?[대화 세션ID]: test40
#
# ========================
#
# 대화를 종료합니다.
# [대화 세션ID]: test40
